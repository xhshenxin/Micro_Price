# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# %%
# rebuild the index of transition matrix
rows=[]
for price_relation_d in range(6):
    for s1_imb_d in range(3):
        for s2_imb_d in range(3):
            s1_imb_d, s2_imb_d, price_relation_d = str(s1_imb_d),str(s2_imb_d),str(price_relation_d)
            rows.append(price_relation_d+s1_imb_d+s2_imb_d)

# %%
markov_adj=pd.read_csv('Markov_exp_move.csv',index_col=0)
markov_adj.index=rows
simu_move=pd.read_csv('simulated_exp_dp.csv',index_col=0)
simu_move.index=rows
markov_adj.columns=simu_move.columns

# %% [markdown]
# ## Compare simulated price movement and Markov adjustment

# %%
diff=markov_adj-simu_move
diff
# Out:
#       exp_dp1   exp_dp2
# 000  0.000000  0.000000
# 001  0.000000  0.000000
# 002  0.000000  0.000000
# 010 -0.000649 -0.001723
# 011  0.000995  0.000848
# 012  0.000000  0.000000
# 020  0.000286 -0.000047
# 021 -0.000295 -0.000862
# 022  0.000000  0.000000
# 100  0.000000  0.000000
# 101  0.000000  0.000000
# 102  0.000000  0.000000
# 110  0.000433 -0.000655
# 111  0.000033 -0.001478
# 112 -0.000117 -0.001368
# 120  0.000428 -0.000819
# 121  0.000371 -0.001003
# 122  0.000426 -0.000228
# 200  0.000603  0.000169
# 201 -0.000059 -0.000536
# 202  0.000000  0.000000
# 210  0.000210 -0.000206
# 211  0.000746  0.000429
# 212 -0.000031 -0.000175
# 220 -0.000758 -0.001596
# 221  0.000504  0.000441
# 222 -0.000018 -0.000002
# 300 -0.000072 -0.000508
# 301 -0.000614 -0.000291
# 302 -0.000272 -0.000124
# 310  0.000071  0.000025
# 311  0.000794  0.002091
# 312 -0.000500  0.000216
# 320  0.000000  0.000000
# 321 -0.000171  0.000176
# 322  0.000307  0.000981
# 400  0.000374  0.001338
# 401  0.000129  0.000983
# 402 -0.000208  0.000689
# 410 -0.000293  0.001028
# 411 -0.001113 -0.000552
# 412 -0.000913 -0.000005
# 420  0.000000  0.000000
# 421  0.000000  0.000000
# 422  0.000000  0.000000
# 500  0.000000  0.000000
# 501 -0.000285  0.000252
# 502  0.000064  0.000317
# 510  0.000000  0.000000
# 511  0.000635  0.001162
# 512  0.000359  0.000413
# 520  0.000000  0.000000
# 521  0.000000  0.000000
# 522  0.000000  0.000000

# %%
diff.plot()

# %%
markov_adj.exp_dp1.plot()
simu_move.exp_dp1.plot()

# %%
markov_adj.exp_dp2.plot()
simu_move.exp_dp2.plot()

# %%
diff.to_csv('markov_minus_simulated.csv')

# %% [markdown]
# ## Plot expected price movement vs its imbalance for each residual state
# ### Markov estimation
# #### Given the other imbalance state = 1

# %%
markov_adj['state']=rows
markov_adj[['res_state','imb1_state','imb2_state']] = markov_adj['state'].str.split('',expand=True).loc[:,1:3].astype('int32')
markov_adj.set_index(['res_state','imb1_state','imb2_state'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-14e638b78e04> in <module>
#       1 markov_adj['state']=rows
# ----> 2 markov_adj[['res_state','imb1_state','imb2_state']] = markov_adj['state'].str.split('',expand=True).loc[:,1:3].astype('int32')
#       3 markov_adj.set_index(['res_state','imb1_state','imb2_state'],inplace=True)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1952                 )
#    1953                 raise TypeError(msg)
# -> 1954             return func(self, *args, **kwargs)
#    1955
#    1956         wrapper.__name__ = func_name
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in split(self, pat, n, expand)
#    2625     @forbid_nonstring_types(["bytes"])
#    2626     def split(self, pat=None, n=-1, expand=False):
# -> 2627         result = str_split(self._parent, pat, n=n)
#    2628         return self._wrap_result(result, expand=expand, returns_string=expand)
#    2629
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in str_split(arr, pat, n)
#    1493             regex = re.compile(pat)
#    1494             f = lambda x: regex.split(x, maxsplit=n)
# -> 1495     res = _na_map(f, arr)
#    1496     return res
#    1497
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in _na_map(f, arr, na_result, dtype)
#     129     if na_result is None:
#     130         na_result = np.nan
# --> 131     return _map_object(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     132
#     133
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in _map_object(f, arr, na_mask, na_value, dtype)
#     214         convert = not np.all(mask)
#     215         try:
# --> 216             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     217         except (TypeError, AttributeError) as e:
#     218             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in <lambda>(x)
#    1492                 n = 0
#    1493             regex = re.compile(pat)
# -> 1494             f = lambda x: regex.split(x, maxsplit=n)
#    1495     res = _na_map(f, arr)
#    1496     return res
#
# ValueError: split() requires a non-empty pattern match.

# %%
markov_adj.xs(1,level='imb2_state').exp_dp1.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 1')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 1')
plt.title('Given imb2_state=1, imb1_state vs exp_dp1 for each residual state')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9cd1729ccb57> in <module>
# ----> 1 markov_adj.xs(1,level='imb2_state').exp_dp1.groupby('res_state').plot()
#       2 plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
#       3 plt.legend()
#       4 plt.xlabel('imbalance state of asset 1')
#       5 plt.xticks(range(3),labels=[0,1,2])
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3515         labels = self._get_axis(axis)
#    3516         if level is not None:
# -> 3517             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3518
#    3519             # create the tuple of the indexer
#
# AttributeError: 'Index' object has no attribute 'get_loc_level'

# %%
markov_adj.xs(1,level='imb1_state').exp_dp2.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 2')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 2')
plt.title('Given imb1_state=1, imb2_state vs exp_dp2 for each residual state')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5a602d0aa55e> in <module>
# ----> 1 markov_adj.xs(1,level='imb1_state').exp_dp2.groupby('res_state').plot()
#       2 plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
#       3 plt.legend()
#       4 plt.xlabel('imbalance state of asset 2')
#       5 plt.xticks(range(3),labels=[0,1,2])
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3515         labels = self._get_axis(axis)
#    3516         if level is not None:
# -> 3517             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3518
#    3519             # create the tuple of the indexer
#
# AttributeError: 'Index' object has no attribute 'get_loc_level'

# %% [markdown]
# #### averaging the other imbalance

# %%
markov_adj.droplevel(2).groupby(['res_state','imb1_state']).mean().exp_dp1.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 1')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 1')
plt.title('Averaging imb2_state, imb1_state vs exp_dp1 for each residual state')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-7457fc14eb97> in <module>
# ----> 1 markov_adj.droplevel(2).groupby(['res_state','imb1_state']).mean().exp_dp1.groupby('res_state').plot()
#       2 plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
#       3 plt.legend()
#       4 plt.xlabel('imbalance state of asset 1')
#       5 plt.xticks(range(3),labels=[0,1,2])
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in droplevel(self, level, axis)
#     743         """
#     744         labels = self._get_axis(axis)
# --> 745         new_labels = labels.droplevel(level)
#     746         result = self.set_axis(new_labels, axis=axis, inplace=False)
#     747         return result
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in droplevel(self, level)
#    1504             level = [level]
#    1505
# -> 1506         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1507
#    1508         if len(level) == 0:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in <genexpr>(.0)
#    1504             level = [level]
#    1505
# -> 1506         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1507
#    1508         if len(level) == 0:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1418
#    1419     def _get_level_number(self, level):
# -> 1420         self._validate_index_level(level)
#    1421         return 0
#    1422
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1410             elif level > 0:
#    1411                 raise IndexError(
# -> 1412                     f"Too many levels: Index has only 1 level, not {level + 1}"
#    1413                 )
#    1414         elif level != self.name:
#
# IndexError: Too many levels: Index has only 1 level, not 3

# %%
markov_adj.droplevel(1).groupby(['res_state','imb2_state']).mean().exp_dp2.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 2')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 2')
plt.title('Averaging imb1_state, imb2_state vs exp_dp2 for each residual state')
# Out:
# Text(0.5, 1.0, 'Averaging imb1_state, imb2_state vs exp_dp2 for each residual state')

# %% [markdown]
# ### Simulated estimation
# #### Given the other imbalance state = 1

# %%
simu_move['state']=rows
simu_move[['res_state','imb1_state','imb2_state']] = simu_move['state'].str.split('',expand=True).loc[:,1:3].astype('int32')
simu_move.set_index(['res_state','imb1_state','imb2_state'],inplace=True)

# %%
simu_move.xs(1,level='imb2_state').exp_dp1.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 1')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 1')
plt.title('Given imb2_state=1, imb1_state vs exp_dp1 for each residual state')
# Out:
# Text(0.5, 1.0, 'Given imb2_state=1, imb1_state vs exp_dp1 for each residual state')

# %%
simu_move.xs(1,level='imb1_state').exp_dp2.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 2')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 2')
plt.title('Given imb1_state=1, imb2_state vs exp_dp2 for each residual state')
# Out:
# Text(0.5, 1.0, 'Given imb1_state=1, imb2_state vs exp_dp2 for each residual state')

# %% [markdown]
# #### averaging the other imbalance

# %%
simu_move.droplevel(2).groupby(['res_state','imb1_state']).mean().exp_dp1.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 1')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 1')
plt.title('Averaging imb2_state, imb1_state vs exp_dp1 for each residual state')
# Out:
# Text(0.5, 1.0, 'Averaging imb2_state, imb1_state vs exp_dp1 for each residual state')

# %%
simu_move.droplevel(1).groupby(['res_state','imb2_state']).mean().exp_dp2.groupby('res_state').plot()
plt.hlines([-0.005,0.005],0,2,colors='k',linestyles='dashed')
plt.legend()
plt.xlabel('imbalance state of asset 2')
plt.xticks(range(3),labels=[0,1,2])
plt.ylabel('expected price movement of asset 2')
plt.title('Averaging imb1_state, imb2_state vs exp_dp2 for each residual state')
# Out:
# Text(0.5, 1.0, 'Averaging imb1_state, imb2_state vs exp_dp2 for each residual state')
